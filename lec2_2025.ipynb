# %%
import torch
from skimage import io, transform
import numpy as np
import torchvision.transforms as T
import matplotlib.pyplot as plt
from PIL import Image

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ## UNET
# - UNet is a particular type of CNN, named after its U shape
# - [Original paper](https://arxiv.org/pdf/1505.04597.pdf)
# <p align="center">
# <img src="unet.png" width="1000" title="Image." >
# </p>

# %%
class conv_block(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size = 3, padding = 1):
        super().__init__()

        self.activation_fn = nn.ReLU()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size = kernel_size, padding = padding)
        self.bn1 = nn.BatchNorm2d(out_channels)

        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size = kernel_size, padding = padding)
        self.bn2 = nn.BatchNorm2d(out_channels)
    
    def forward(self, inputs):
        x = self.conv1(inputs)
        x = self.bn1(x)
        x = self.activation_fn(x)
        
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.activation_fn(x)
        return x
    
class down_block(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = conv_block(in_channels, out_channels)
        self.pool = nn.MaxPool2d((2,2))

    def forward(self, inputs):
        x = self.conv(inputs)
        p = self.pool(x)
        return x,p

class up_block(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_channels, out_channels, kernel_size = 2, stride = 2, padding = 0)
        self.conv = conv_block(out_channels+out_channels, out_channels)
    
    def forward(self, inputs, skip): #inputs [bs,30,7,7]
        x = self.up(inputs) #inputs [bs,20,14,14]
        x = torch.cat([x, skip], axis=1) # if skip is of size [bs,50,14,14]. then x is now of size [bs,70,14,14]
        x = self.conv(x) # [bs, out_channels, 14,14]
        return x


class UNet(nn.Module):

    def __init__(self, in_channels=3, out_channels = 1, f = [64,128,256,512,1024]):
        super().__init__()
        
        #f = [8,8,8,8,8]

        self.encoder1 = down_block(in_channels, f[0])
        self.encoder2 = down_block(f[0],f[1])
        self.encoder3 = down_block(f[1],f[2])
        self.encoder4 = down_block(f[2],f[3])

        self.bottleneck = conv_block(f[3],f[4])

        self.decoder1 = up_block(f[4],f[3])
        self.decoder2 = up_block(f[3],f[2])
        self.decoder3 = up_block(f[2],f[1])
        self.decoder4 = up_block(f[1],f[0])

        self.outputs = nn.Conv2d(f[0], out_channels, kernel_size = 1, padding = 0)
        self.sigmoid_layer = nn.Sigmoid()

    def forward(self, inputs):
        c1, p1 = self.encoder1(inputs)
        c2, p2 = self.encoder2(p1)
        c3, p3 = self.encoder3(p2)
        c4, p4 = self.encoder4(p3)

        bn = self.bottleneck(p4)

        d1 = self.decoder1(bn, c4)
        d2 = self.decoder2(d1, c3)
        d3 = self.decoder3(d2, c2)
        d4 = self.decoder4(d3, c1)

        outputs = self.outputs(d4)
        outputs = self.sigmoid_layer(outputs)
        
        plot = True
        if plot:
            print('Input shape', inputs.shape)
            print('After layer 1', p1.shape)
            print('After layer 2', p2.shape)
            print('After layer 3', p3.shape)
            print('After layer 4', p4.shape)
            print('After bn', bn.shape)
            print('After layer 6', d1.shape)
            print('After layer 7', d2.shape)
            print('After layer 8', d3.shape)
            print('After layer 9', d4.shape)
            print('Output shape', outputs.shape)

        return outputs
UNet = UNet()

x = torch.zeros([1,3,256,256])
y = UNet(x)
# Out:
# Input shape torch.Size([1, 3, 256, 256])
# After layer 1 torch.Size([1, 64, 128, 128])
# After layer 2 torch.Size([1, 128, 64, 64])
# After layer 3 torch.Size([1, 256, 32, 32])
# After layer 4 torch.Size([1, 512, 16, 16])
# After bn torch.Size([1, 1024, 16, 16])
# After layer 6 torch.Size([1, 512, 32, 32])
# After layer 7 torch.Size([1, 256, 64, 64])
# After layer 8 torch.Size([1, 128, 128, 128])
# After layer 9 torch.Size([1, 64, 256, 256])
# Output shape torch.Size([1, 1, 256, 256])

# %% [markdown]
# ## Segmentation
#
# - Image segmentation is the task of partitioning an image, or identifying an object in an image
# - Particular value in medical imaging, highlighting objects of interest
#
# <p align="center">
# <img src="./DRIVE/training/images/21_training.png" width="200" title="Image." >
# </p>
# <p align="center">
# <img src="./DRIVE/training/1st_manual/21_manual1.png" width="200" title="Image." >
# </p>
#
# - The target image is a binary image, where pixels = 0 are background and pixels = 1 are foreground. We want the network to output a binary image replicating this.

# %%
def get_paths(base_path='./DRIVE/'):
    train_im_paths = []
    train_gt_paths = []
    test_im_paths = []
    test_gt_paths = []
    
    for i in range(21, 41):
        train_im_paths.append(base_path + 'training/images/%d_training.tif'%(i))
        train_gt_paths.append(base_path + 'training/1st_manual/%d_manual1.gif'%(i))

    for i in range(1, 21):
        test_im_paths.append(base_path + 'test/images/%d_test.tif'%(i))
        test_gt_paths.append(base_path + 'test/1st_manual/%d_manual1.gif'%(i))
        
    train_paths = [train_im_paths,train_gt_paths]
    test_paths = [test_im_paths,test_gt_paths]
    return train_paths, test_paths

# %%
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, paths):
        # TODO
        # 1. Initialize file paths or a list of file names. 
        self.im_paths = paths[0]
        self.gt_paths = paths[1]
        self.preprocesses = T.Compose([
            T.Resize((256,256)),
            T.ToTensor(),
        ])
        pass
    def __getitem__(self, index):
        # TODO
        # 1. Read one data from file (e.g. using numpy.fromfile, PIL.Image.open).
        image = Image.open(self.im_paths[index])
        label = Image.open(self.gt_paths[index])
        # 2. Preprocess the data (e.g. torchvision.Transform).
        
        image = self.preprocesses(image)
        label = self.preprocesses(label)
        
        #Ensure gt is binary
        label[label>.5] = 1
        label[label<=.5]=0
        # 3. Return a data pair (e.g. image and label).
        return image, label
        
    def __len__(self):
        return len(self.im_paths)
    

train_paths, test_paths = get_paths()
    
custom_dataset = CustomDataset(train_paths)
train_loader = torch.utils.data.DataLoader(dataset=custom_dataset,
                                           batch_size=4, 
                                           shuffle=True)

# %%
print(train_paths[0])
print(train_paths[1])
# Out:
# ['./DRIVE/training/images/21_training.tif', './DRIVE/training/images/22_training.tif', './DRIVE/training/images/23_training.tif', './DRIVE/training/images/24_training.tif', './DRIVE/training/images/25_training.tif', './DRIVE/training/images/26_training.tif', './DRIVE/training/images/27_training.tif', './DRIVE/training/images/28_training.tif', './DRIVE/training/images/29_training.tif', './DRIVE/training/images/30_training.tif', './DRIVE/training/images/31_training.tif', './DRIVE/training/images/32_training.tif', './DRIVE/training/images/33_training.tif', './DRIVE/training/images/34_training.tif', './DRIVE/training/images/35_training.tif', './DRIVE/training/images/36_training.tif', './DRIVE/training/images/37_training.tif', './DRIVE/training/images/38_training.tif', './DRIVE/training/images/39_training.tif', './DRIVE/training/images/40_training.tif']
# ['./DRIVE/training/1st_manual/21_manual1.gif', './DRIVE/training/1st_manual/22_manual1.gif', './DRIVE/training/1st_manual/23_manual1.gif', './DRIVE/training/1st_manual/24_manual1.gif', './DRIVE/training/1st_manual/25_manual1.gif', './DRIVE/training/1st_manual/26_manual1.gif', './DRIVE/training/1st_manual/27_manual1.gif', './DRIVE/training/1st_manual/28_manual1.gif', './DRIVE/training/1st_manual/29_manual1.gif', './DRIVE/training/1st_manual/30_manual1.gif', './DRIVE/training/1st_manual/31_manual1.gif', './DRIVE/training/1st_manual/32_manual1.gif', './DRIVE/training/1st_manual/33_manual1.gif', './DRIVE/training/1st_manual/34_manual1.gif', './DRIVE/training/1st_manual/35_manual1.gif', './DRIVE/training/1st_manual/36_manual1.gif', './DRIVE/training/1st_manual/37_manual1.gif', './DRIVE/training/1st_manual/38_manual1.gif', './DRIVE/training/1st_manual/39_manual1.gif', './DRIVE/training/1st_manual/40_manual1.gif']

# %%
print(train_loader)
data_iter = iter(train_loader)
image,label = next(data_iter)
print(image.size())
print(label.size())

label = torch.squeeze(label)
print(label.size())
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x000001968D8F0040>
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 1, 256, 256])
# torch.Size([4, 256, 256])

# %%
im,label = custom_dataset[1]
print(im.size())
print(label.size())

plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plt.imshow(im.permute(1, 2, 0))
plt.subplot(1,2,2)
plt.imshow(label[0,:,:])
# Out:
# torch.Size([3, 256, 256])
# torch.Size([1, 256, 256])

# %%
class CNN(nn.Module):
    def __init__(self,in_channels,out_channels):
        super(CNN, self).__init__()
        f = [8,16,32,16,8,out_channels]
# Input to conv1 will be image of shape [batch_size,1,img_size,img_size]
        self.conv1 = nn.Sequential(   
            nn.Conv2d(in_channels=in_channels,out_channels=f[0],kernel_size=(3,3),padding=1), 
            nn.ReLU(), 
            nn.MaxPool2d(kernel_size=(2,2)) 
        )
        self.conv2 = nn.Sequential( 
            nn.Conv2d(in_channels=f[0],out_channels=f[1],kernel_size=(3,3),padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2,2)) 
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=f[1],out_channels=f[2],kernel_size=(3,3),padding=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=f[2],out_channels=f[2],kernel_size=(3,3),padding=1),
            nn.ReLU()
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=f[2],out_channels=f[3],kernel_size=(3,3),padding=1),
            nn.ReLU(),
            nn.Upsample(scale_factor=2))
        
        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=f[3],out_channels=f[4],kernel_size=(3,3),padding=1),
            nn.ReLU(),
            nn.Upsample(scale_factor=2))
        
        
        self.conv6 = nn.Sequential(
            nn.Conv2d(in_channels=f[4],out_channels=f[5],kernel_size=(1,1)),
            nn.Sigmoid()
        )
            

    def forward(self, x,plot=False):

        x1 = self.conv1(x)
        x2 = self.conv2(x1)
        x3 = self.conv3(x2)
        x4 = self.conv4(x3)
        x5 = self.conv5(x4)
        x6 = self.conv6(x5)
        
        if plot:
            print('Input shape', x.shape)
            print('After layer 1', x1.shape)
            print('After layer 2', x2.shape)
            print('After layer 3', x3.shape)
            print('After layer 4', x4.shape)
            print('After layer 5', x5.shape)
            print('After layer 6', x6.shape)

        return x6

model = CNN(in_channels=3, out_channels=1)

# %%
learning_rate = 0.001

optimizer = optim.Adam(model.parameters(), lr = learning_rate)   
loss_func = nn.BCELoss()

# %%
from torch.autograd import Variable

num_epochs = 200

def train(num_epochs, model, train_loader):
    
    model.train()
        
    # Train the model
    total_step = len(train_loader)
        
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(train_loader):
            
            # gives batch data, normalize x when iterate train_loader
            b_x = Variable(images)   # batch x
            b_y = Variable(labels)   # batch y
            output = model(b_x)  
            #loss = loss_func(torch.squeeze(output), torch.squeeze(b_y))
            loss = loss_func(output, b_y)
            
            # clear gradients for this training step   
            optimizer.zero_grad()           
            
            # backpropagation, compute gradients 
            loss.backward()                # apply gradients             
            optimizer.step()                
            
            if (i+1) % 2 == 0:
                print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                       .format(epoch + 1, num_epochs, i + 1, total_step, loss.item()))               
        
    
    
train(num_epochs, model, train_loader)
# Out:
# Epoch [1/400], Step [2/5], Loss: 0.6962
# Epoch [1/400], Step [4/5], Loss: 0.6897
# Epoch [2/400], Step [2/5], Loss: 0.6760
# Epoch [2/400], Step [4/5], Loss: 0.6558
# Epoch [3/400], Step [2/5], Loss: 0.5748
# Epoch [3/400], Step [4/5], Loss: 0.5045
# Epoch [4/400], Step [2/5], Loss: 0.3668
# Epoch [4/400], Step [4/5], Loss: 0.4074
# Epoch [5/400], Step [2/5], Loss: 0.4299
# Epoch [5/400], Step [4/5], Loss: 0.3882
# Epoch [6/400], Step [2/5], Loss: 0.3606
# Epoch [6/400], Step [4/5], Loss: 0.3319
# Epoch [7/400], Step [2/5], Loss: 0.3316
# Epoch [7/400], Step [4/5], Loss: 0.2745
# Epoch [8/400], Step [2/5], Loss: 0.2860
# Epoch [8/400], Step [4/5], Loss: 0.2717
# Epoch [9/400], Step [2/5], Loss: 0.2461
# Epoch [9/400], Step [4/5], Loss: 0.2804
# Epoch [10/400], Step [2/5], Loss: 0.2437
# Epoch [10/400], Step [4/5], Loss: 0.2610
# Epoch [11/400], Step [2/5], Loss: 0.2613
# Epoch [11/400], Step [4/5], Loss: 0.2413
# Epoch [12/400], Step [2/5], Loss: 0.2566
# Epoch [12/400], Step [4/5], Loss: 0.2638
# Epoch [13/400], Step [2/5], Loss: 0.2578
# Epoch [13/400], Step [4/5], Loss: 0.2714
# Epoch [14/400], Step [2/5], Loss: 0.2525
# Epoch [14/400], Step [4/5], Loss: 0.2531
# Epoch [15/400], Step [2/5], Loss: 0.2641
# Epoch [15/400], Step [4/5], Loss: 0.2376
# Epoch [16/400], Step [2/5], Loss: 0.2396
# Epoch [16/400], Step [4/5], Loss: 0.2375
# Epoch [17/400], Step [2/5], Loss: 0.2752
# Epoch [17/400], Step [4/5], Loss: 0.2428
# Epoch [18/400], Step [2/5], Loss: 0.2544
# Epoch [18/400], Step [4/5], Loss: 0.2291
# Epoch [19/400], Step [2/5], Loss: 0.2518
# Epoch [19/400], Step [4/5], Loss: 0.2508
# Epoch [20/400], Step [2/5], Loss: 0.2492
# Epoch [20/400], Step [4/5], Loss: 0.2469
# Epoch [21/400], Step [2/5], Loss: 0.2490
# Epoch [21/400], Step [4/5], Loss: 0.2319
# Epoch [22/400], Step [2/5], Loss: 0.2476
# Epoch [22/400], Step [4/5], Loss: 0.2659
# Epoch [23/400], Step [2/5], Loss: 0.2315
# Epoch [23/400], Step [4/5], Loss: 0.2542
# Epoch [24/400], Step [2/5], Loss: 0.2499
# Epoch [24/400], Step [4/5], Loss: 0.2201
# Epoch [25/400], Step [2/5], Loss: 0.2390
# Epoch [25/400], Step [4/5], Loss: 0.2497
# Epoch [26/400], Step [2/5], Loss: 0.2375
# Epoch [26/400], Step [4/5], Loss: 0.2553
# Epoch [27/400], Step [2/5], Loss: 0.2358
# Epoch [27/400], Step [4/5], Loss: 0.2383
# Epoch [28/400], Step [2/5], Loss: 0.2628
# Epoch [28/400], Step [4/5], Loss: 0.2363
# Epoch [29/400], Step [2/5], Loss: 0.2617
# Epoch [29/400], Step [4/5], Loss: 0.2699
# Epoch [30/400], Step [2/5], Loss: 0.2268
# Epoch [30/400], Step [4/5], Loss: 0.2536
# Epoch [31/400], Step [2/5], Loss: 0.2302
# Epoch [31/400], Step [4/5], Loss: 0.2590
# Epoch [32/400], Step [2/5], Loss: 0.2483
# Epoch [32/400], Step [4/5], Loss: 0.2589
# Epoch [33/400], Step [2/5], Loss: 0.2388
# Epoch [33/400], Step [4/5], Loss: 0.2730
# Epoch [34/400], Step [2/5], Loss: 0.2458
# Epoch [34/400], Step [4/5], Loss: 0.2359
# Epoch [35/400], Step [2/5], Loss: 0.2592
# Epoch [35/400], Step [4/5], Loss: 0.2646
# Epoch [36/400], Step [2/5], Loss: 0.2474
# Epoch [36/400], Step [4/5], Loss: 0.2417
# Epoch [37/400], Step [2/5], Loss: 0.2644
# Epoch [37/400], Step [4/5], Loss: 0.2437
# Epoch [38/400], Step [2/5], Loss: 0.2556
# Epoch [38/400], Step [4/5], Loss: 0.2282
# Epoch [39/400], Step [2/5], Loss: 0.2443
# Epoch [39/400], Step [4/5], Loss: 0.2577
# Epoch [40/400], Step [2/5], Loss: 0.2412
# Epoch [40/400], Step [4/5], Loss: 0.2643
# Epoch [41/400], Step [2/5], Loss: 0.2675
# Epoch [41/400], Step [4/5], Loss: 0.2473
# Epoch [42/400], Step [2/5], Loss: 0.2410
# Epoch [42/400], Step [4/5], Loss: 0.2395
# Epoch [43/400], Step [2/5], Loss: 0.2647
# Epoch [43/400], Step [4/5], Loss: 0.2525
# Epoch [44/400], Step [2/5], Loss: 0.2153
# Epoch [44/400], Step [4/5], Loss: 0.2567
# Epoch [45/400], Step [2/5], Loss: 0.2355
# Epoch [45/400], Step [4/5], Loss: 0.2546
# Epoch [46/400], Step [2/5], Loss: 0.2600
# Epoch [46/400], Step [4/5], Loss: 0.2582
# Epoch [47/400], Step [2/5], Loss: 0.2330
# Epoch [47/400], Step [4/5], Loss: 0.2457
# Epoch [48/400], Step [2/5], Loss: 0.2284
# Epoch [48/400], Step [4/5], Loss: 0.2429
# Epoch [49/400], Step [2/5], Loss: 0.2493
# Epoch [49/400], Step [4/5], Loss: 0.2428
# Epoch [50/400], Step [2/5], Loss: 0.2541
# Epoch [50/400], Step [4/5], Loss: 0.2320
# Epoch [51/400], Step [2/5], Loss: 0.2472
# Epoch [51/400], Step [4/5], Loss: 0.2368
# Epoch [52/400], Step [2/5], Loss: 0.2356
# Epoch [52/400], Step [4/5], Loss: 0.2507
# Epoch [53/400], Step [2/5], Loss: 0.2308
# Epoch [53/400], Step [4/5], Loss: 0.2510
# Epoch [54/400], Step [2/5], Loss: 0.2364
# Epoch [54/400], Step [4/5], Loss: 0.2349
# Epoch [55/400], Step [2/5], Loss: 0.2416
# Epoch [55/400], Step [4/5], Loss: 0.2265
# Epoch [56/400], Step [2/5], Loss: 0.2570
# Epoch [56/400], Step [4/5], Loss: 0.2476
# Epoch [57/400], Step [2/5], Loss: 0.2642
# Epoch [57/400], Step [4/5], Loss: 0.2342
# Epoch [58/400], Step [2/5], Loss: 0.2437
# Epoch [58/400], Step [4/5], Loss: 0.2425
# Epoch [59/400], Step [2/5], Loss: 0.2524
# Epoch [59/400], Step [4/5], Loss: 0.2284
# Epoch [60/400], Step [2/5], Loss: 0.2411
# Epoch [60/400], Step [4/5], Loss: 0.2304
# Epoch [61/400], Step [2/5], Loss: 0.2450
# Epoch [61/400], Step [4/5], Loss: 0.2654
# Epoch [62/400], Step [2/5], Loss: 0.2484
# Epoch [62/400], Step [4/5], Loss: 0.2482
# Epoch [63/400], Step [2/5], Loss: 0.2444
# Epoch [63/400], Step [4/5], Loss: 0.2413
# Epoch [64/400], Step [2/5], Loss: 0.2578
# Epoch [64/400], Step [4/5], Loss: 0.2431
# Epoch [65/400], Step [2/5], Loss: 0.2429
# Epoch [65/400], Step [4/5], Loss: 0.2507
# Epoch [66/400], Step [2/5], Loss: 0.2363
# Epoch [66/400], Step [4/5], Loss: 0.2341
# Epoch [67/400], Step [2/5], Loss: 0.2407
# Epoch [67/400], Step [4/5], Loss: 0.2476
# Epoch [68/400], Step [2/5], Loss: 0.2593
# Epoch [68/400], Step [4/5], Loss: 0.2495
# Epoch [69/400], Step [2/5], Loss: 0.2349
# Epoch [69/400], Step [4/5], Loss: 0.2509
# Epoch [70/400], Step [2/5], Loss: 0.2721
# Epoch [70/400], Step [4/5], Loss: 0.2265
# Epoch [71/400], Step [2/5], Loss: 0.2680
# Epoch [71/400], Step [4/5], Loss: 0.2336
# Epoch [72/400], Step [2/5], Loss: 0.2368
# Epoch [72/400], Step [4/5], Loss: 0.2635
# Epoch [73/400], Step [2/5], Loss: 0.2389
# Epoch [73/400], Step [4/5], Loss: 0.2436
# Epoch [74/400], Step [2/5], Loss: 0.2248
# Epoch [74/400], Step [4/5], Loss: 0.2337
# Epoch [75/400], Step [2/5], Loss: 0.2470
# Epoch [75/400], Step [4/5], Loss: 0.2624
# Epoch [76/400], Step [2/5], Loss: 0.2560
# Epoch [76/400], Step [4/5], Loss: 0.2269
# Epoch [77/400], Step [2/5], Loss: 0.2405
# Epoch [77/400], Step [4/5], Loss: 0.2440
# Epoch [78/400], Step [2/5], Loss: 0.2503
# Epoch [78/400], Step [4/5], Loss: 0.2492
# Epoch [79/400], Step [2/5], Loss: 0.2335
# Epoch [79/400], Step [4/5], Loss: 0.2632
# Epoch [80/400], Step [2/5], Loss: 0.2373
# Epoch [80/400], Step [4/5], Loss: 0.2608
# Epoch [81/400], Step [2/5], Loss: 0.2402
# Epoch [81/400], Step [4/5], Loss: 0.2423
# Epoch [82/400], Step [2/5], Loss: 0.2489
# Epoch [82/400], Step [4/5], Loss: 0.2289
# Epoch [83/400], Step [2/5], Loss: 0.2486
# Epoch [83/400], Step [4/5], Loss: 0.2271
# Epoch [84/400], Step [2/5], Loss: 0.2382
# Epoch [84/400], Step [4/5], Loss: 0.2351
# Epoch [85/400], Step [2/5], Loss: 0.2581
# Epoch [85/400], Step [4/5], Loss: 0.2533
# Epoch [86/400], Step [2/5], Loss: 0.2330
# Epoch [86/400], Step [4/5], Loss: 0.2385
# Epoch [87/400], Step [2/5], Loss: 0.2566
# Epoch [87/400], Step [4/5], Loss: 0.2418
# Epoch [88/400], Step [2/5], Loss: 0.2393
# Epoch [88/400], Step [4/5], Loss: 0.2532
# Epoch [89/400], Step [2/5], Loss: 0.2505
# Epoch [89/400], Step [4/5], Loss: 0.2194
# Epoch [90/400], Step [2/5], Loss: 0.2713
# Epoch [90/400], Step [4/5], Loss: 0.2295
# Epoch [91/400], Step [2/5], Loss: 0.2389
# Epoch [91/400], Step [4/5], Loss: 0.2442
# Epoch [92/400], Step [2/5], Loss: 0.2503
# Epoch [92/400], Step [4/5], Loss: 0.2315
# Epoch [93/400], Step [2/5], Loss: 0.2358
# Epoch [93/400], Step [4/5], Loss: 0.2672
# Epoch [94/400], Step [2/5], Loss: 0.2353
# Epoch [94/400], Step [4/5], Loss: 0.2695
# Epoch [95/400], Step [2/5], Loss: 0.2368
# Epoch [95/400], Step [4/5], Loss: 0.2543
# Epoch [96/400], Step [2/5], Loss: 0.2295
# Epoch [96/400], Step [4/5], Loss: 0.2421
# Epoch [97/400], Step [2/5], Loss: 0.2368
# Epoch [97/400], Step [4/5], Loss: 0.2404
# Epoch [98/400], Step [2/5], Loss: 0.2701
# Epoch [98/400], Step [4/5], Loss: 0.2450
# Epoch [99/400], Step [2/5], Loss: 0.2635
# Epoch [99/400], Step [4/5], Loss: 0.2410
# Epoch [100/400], Step [2/5], Loss: 0.2602
# Epoch [100/400], Step [4/5], Loss: 0.2337
# Epoch [101/400], Step [2/5], Loss: 0.2264
# Epoch [101/400], Step [4/5], Loss: 0.2522
# Epoch [102/400], Step [2/5], Loss: 0.2397
# Epoch [102/400], Step [4/5], Loss: 0.2386
# Epoch [103/400], Step [2/5], Loss: 0.2360
# Epoch [103/400], Step [4/5], Loss: 0.2418
# Epoch [104/400], Step [2/5], Loss: 0.2454
# Epoch [104/400], Step [4/5], Loss: 0.2497
# Epoch [105/400], Step [2/5], Loss: 0.2491
# Epoch [105/400], Step [4/5], Loss: 0.2236
# Epoch [106/400], Step [2/5], Loss: 0.2349
# Epoch [106/400], Step [4/5], Loss: 0.2463
# Epoch [107/400], Step [2/5], Loss: 0.2482
# Epoch [107/400], Step [4/5], Loss: 0.2427
# Epoch [108/400], Step [2/5], Loss: 0.2503
# Epoch [108/400], Step [4/5], Loss: 0.2349
# Epoch [109/400], Step [2/5], Loss: 0.2292
# Epoch [109/400], Step [4/5], Loss: 0.2386
# Epoch [110/400], Step [2/5], Loss: 0.2399
# Epoch [110/400], Step [4/5], Loss: 0.2435
# Epoch [111/400], Step [2/5], Loss: 0.2392
# Epoch [111/400], Step [4/5], Loss: 0.2544
# Epoch [112/400], Step [2/5], Loss: 0.2587
# Epoch [112/400], Step [4/5], Loss: 0.2267
# Epoch [113/400], Step [2/5], Loss: 0.2281
# Epoch [113/400], Step [4/5], Loss: 0.2457
# Epoch [114/400], Step [2/5], Loss: 0.2564
# Epoch [114/400], Step [4/5], Loss: 0.2382
# Epoch [115/400], Step [2/5], Loss: 0.2267
# Epoch [115/400], Step [4/5], Loss: 0.2349
# Epoch [116/400], Step [2/5], Loss: 0.2398
# Epoch [116/400], Step [4/5], Loss: 0.2407
# Epoch [117/400], Step [2/5], Loss: 0.2467
# Epoch [117/400], Step [4/5], Loss: 0.2481
# Epoch [118/400], Step [2/5], Loss: 0.2284
# Epoch [118/400], Step [4/5], Loss: 0.2398
# Epoch [119/400], Step [2/5], Loss: 0.2490
# Epoch [119/400], Step [4/5], Loss: 0.2439
# Epoch [120/400], Step [2/5], Loss: 0.2324
# Epoch [120/400], Step [4/5], Loss: 0.2583
# Epoch [121/400], Step [2/5], Loss: 0.2676
# Epoch [121/400], Step [4/5], Loss: 0.2315
# Epoch [122/400], Step [2/5], Loss: 0.2523
# Epoch [122/400], Step [4/5], Loss: 0.2444
# Epoch [123/400], Step [2/5], Loss: 0.2539
# Epoch [123/400], Step [4/5], Loss: 0.2299
# Epoch [124/400], Step [2/5], Loss: 0.2247
# Epoch [124/400], Step [4/5], Loss: 0.2670
# Epoch [125/400], Step [2/5], Loss: 0.2663
# Epoch [125/400], Step [4/5], Loss: 0.2392
# Epoch [126/400], Step [2/5], Loss: 0.2494
# Epoch [126/400], Step [4/5], Loss: 0.2598
# Epoch [127/400], Step [2/5], Loss: 0.2389
# Epoch [127/400], Step [4/5], Loss: 0.2573
# Epoch [128/400], Step [2/5], Loss: 0.2349
# Epoch [128/400], Step [4/5], Loss: 0.2462
# Epoch [129/400], Step [2/5], Loss: 0.2383
# Epoch [129/400], Step [4/5], Loss: 0.2373
# Epoch [130/400], Step [2/5], Loss: 0.2185
# Epoch [130/400], Step [4/5], Loss: 0.2613
# Epoch [131/400], Step [2/5], Loss: 0.2508
# Epoch [131/400], Step [4/5], Loss: 0.2418
# Epoch [132/400], Step [2/5], Loss: 0.2429
# Epoch [132/400], Step [4/5], Loss: 0.2680
# Epoch [133/400], Step [2/5], Loss: 0.2397
# Epoch [133/400], Step [4/5], Loss: 0.2439
# Epoch [134/400], Step [2/5], Loss: 0.2388
# Epoch [134/400], Step [4/5], Loss: 0.2280
# Epoch [135/400], Step [2/5], Loss: 0.2429
# Epoch [135/400], Step [4/5], Loss: 0.2215
# Epoch [136/400], Step [2/5], Loss: 0.2507
# Epoch [136/400], Step [4/5], Loss: 0.2162
# Epoch [137/400], Step [2/5], Loss: 0.2395
# Epoch [137/400], Step [4/5], Loss: 0.2411
# Epoch [138/400], Step [2/5], Loss: 0.2522
# Epoch [138/400], Step [4/5], Loss: 0.2546
# Epoch [139/400], Step [2/5], Loss: 0.2589
# Epoch [139/400], Step [4/5], Loss: 0.2397
# Epoch [140/400], Step [2/5], Loss: 0.2268
# Epoch [140/400], Step [4/5], Loss: 0.2502
# Epoch [141/400], Step [2/5], Loss: 0.2381
# Epoch [141/400], Step [4/5], Loss: 0.2663
# Epoch [142/400], Step [2/5], Loss: 0.2534
# Epoch [142/400], Step [4/5], Loss: 0.2584
# Epoch [143/400], Step [2/5], Loss: 0.2296
# Epoch [143/400], Step [4/5], Loss: 0.2425
# Epoch [144/400], Step [2/5], Loss: 0.2528
# Epoch [144/400], Step [4/5], Loss: 0.2242
# Epoch [145/400], Step [2/5], Loss: 0.2462
# Epoch [145/400], Step [4/5], Loss: 0.2605
# Epoch [146/400], Step [2/5], Loss: 0.2404
# Epoch [146/400], Step [4/5], Loss: 0.2537
# Epoch [147/400], Step [2/5], Loss: 0.2599
# Epoch [147/400], Step [4/5], Loss: 0.2255
# Epoch [148/400], Step [2/5], Loss: 0.2324
# Epoch [148/400], Step [4/5], Loss: 0.2353
# Epoch [149/400], Step [2/5], Loss: 0.2259
# Epoch [149/400], Step [4/5], Loss: 0.2488
# Epoch [150/400], Step [2/5], Loss: 0.2366
# Epoch [150/400], Step [4/5], Loss: 0.2442
# Epoch [151/400], Step [2/5], Loss: 0.2261
# Epoch [151/400], Step [4/5], Loss: 0.2378
# Epoch [152/400], Step [2/5], Loss: 0.2239
# Epoch [152/400], Step [4/5], Loss: 0.2430
# Epoch [153/400], Step [2/5], Loss: 0.2203
# Epoch [153/400], Step [4/5], Loss: 0.2602
# Epoch [154/400], Step [2/5], Loss: 0.2255
# Epoch [154/400], Step [4/5], Loss: 0.2481
# Epoch [155/400], Step [2/5], Loss: 0.2345
# Epoch [155/400], Step [4/5], Loss: 0.2358
# Epoch [156/400], Step [2/5], Loss: 0.2363
# Epoch [156/400], Step [4/5], Loss: 0.2466
# Epoch [157/400], Step [2/5], Loss: 0.2165
# Epoch [157/400], Step [4/5], Loss: 0.2336
# Epoch [158/400], Step [2/5], Loss: 0.2478
# Epoch [158/400], Step [4/5], Loss: 0.2377
# Epoch [159/400], Step [2/5], Loss: 0.2401
# Epoch [159/400], Step [4/5], Loss: 0.2263
# Epoch [160/400], Step [2/5], Loss: 0.2399
# Epoch [160/400], Step [4/5], Loss: 0.2414
# Epoch [161/400], Step [2/5], Loss: 0.2451
# Epoch [161/400], Step [4/5], Loss: 0.2441
# Epoch [162/400], Step [2/5], Loss: 0.2483
# Epoch [162/400], Step [4/5], Loss: 0.2415
# Epoch [163/400], Step [2/5], Loss: 0.2467
# Epoch [163/400], Step [4/5], Loss: 0.2521
# Epoch [164/400], Step [2/5], Loss: 0.2222
# Epoch [164/400], Step [4/5], Loss: 0.2304
# Epoch [165/400], Step [2/5], Loss: 0.2573
# Epoch [165/400], Step [4/5], Loss: 0.2295
# Epoch [166/400], Step [2/5], Loss: 0.2327
# Epoch [166/400], Step [4/5], Loss: 0.2354
# Epoch [167/400], Step [2/5], Loss: 0.2340
# Epoch [167/400], Step [4/5], Loss: 0.2390
# Epoch [168/400], Step [2/5], Loss: 0.2666
# Epoch [168/400], Step [4/5], Loss: 0.2395
# Epoch [169/400], Step [2/5], Loss: 0.2474
# Epoch [169/400], Step [4/5], Loss: 0.2363
# Epoch [170/400], Step [2/5], Loss: 0.2453
# Epoch [170/400], Step [4/5], Loss: 0.2226
# Epoch [171/400], Step [2/5], Loss: 0.2565
# Epoch [171/400], Step [4/5], Loss: 0.2321
# Epoch [172/400], Step [2/5], Loss: 0.2283
# Epoch [172/400], Step [4/5], Loss: 0.2402
# Epoch [173/400], Step [2/5], Loss: 0.2383
# Epoch [173/400], Step [4/5], Loss: 0.2315
# Epoch [174/400], Step [2/5], Loss: 0.2354
# Epoch [174/400], Step [4/5], Loss: 0.2468
# Epoch [175/400], Step [2/5], Loss: 0.2549
# Epoch [175/400], Step [4/5], Loss: 0.2279
# Epoch [176/400], Step [2/5], Loss: 0.2351
# Epoch [176/400], Step [4/5], Loss: 0.2624
# Epoch [177/400], Step [2/5], Loss: 0.2319
# Epoch [177/400], Step [4/5], Loss: 0.2200
# Epoch [178/400], Step [2/5], Loss: 0.2469
# Epoch [178/400], Step [4/5], Loss: 0.2149
# Epoch [179/400], Step [2/5], Loss: 0.2284
# Epoch [179/400], Step [4/5], Loss: 0.2388
# Epoch [180/400], Step [2/5], Loss: 0.2377
# Epoch [180/400], Step [4/5], Loss: 0.2678
# Epoch [181/400], Step [2/5], Loss: 0.2575
# Epoch [181/400], Step [4/5], Loss: 0.2283
# Epoch [182/400], Step [2/5], Loss: 0.2387
# Epoch [182/400], Step [4/5], Loss: 0.2247
# Epoch [183/400], Step [2/5], Loss: 0.2220
# Epoch [183/400], Step [4/5], Loss: 0.2380
# Epoch [184/400], Step [2/5], Loss: 0.2590
# Epoch [184/400], Step [4/5], Loss: 0.2263
# Epoch [185/400], Step [2/5], Loss: 0.2429
# Epoch [185/400], Step [4/5], Loss: 0.2044
# Epoch [186/400], Step [2/5], Loss: 0.2333
# Epoch [186/400], Step [4/5], Loss: 0.2342
# Epoch [187/400], Step [2/5], Loss: 0.2251
# Epoch [187/400], Step [4/5], Loss: 0.2412
# Epoch [188/400], Step [2/5], Loss: 0.2492
# Epoch [188/400], Step [4/5], Loss: 0.2395
# Epoch [189/400], Step [2/5], Loss: 0.2538
# Epoch [189/400], Step [4/5], Loss: 0.2410
# Epoch [190/400], Step [2/5], Loss: 0.2451
# Epoch [190/400], Step [4/5], Loss: 0.2354
# Epoch [191/400], Step [2/5], Loss: 0.2566
# Epoch [191/400], Step [4/5], Loss: 0.2277
# Epoch [192/400], Step [2/5], Loss: 0.2475
# Epoch [192/400], Step [4/5], Loss: 0.2227
# Epoch [193/400], Step [2/5], Loss: 0.2417
# Epoch [193/400], Step [4/5], Loss: 0.2247
# Epoch [194/400], Step [2/5], Loss: 0.2315
# Epoch [194/400], Step [4/5], Loss: 0.2334
# Epoch [195/400], Step [2/5], Loss: 0.2138
# Epoch [195/400], Step [4/5], Loss: 0.2445
# Epoch [196/400], Step [2/5], Loss: 0.2253
# Epoch [196/400], Step [4/5], Loss: 0.2313
# Epoch [197/400], Step [2/5], Loss: 0.2484
# Epoch [197/400], Step [4/5], Loss: 0.1976
# Epoch [198/400], Step [2/5], Loss: 0.2281
# Epoch [198/400], Step [4/5], Loss: 0.2181
# Epoch [199/400], Step [2/5], Loss: 0.2366
# Epoch [199/400], Step [4/5], Loss: 0.2236
# Epoch [200/400], Step [2/5], Loss: 0.2211
# Epoch [200/400], Step [4/5], Loss: 0.2194
# Epoch [201/400], Step [2/5], Loss: 0.2196
# Epoch [201/400], Step [4/5], Loss: 0.2181
# Epoch [202/400], Step [2/5], Loss: 0.2155
# Epoch [202/400], Step [4/5], Loss: 0.2352
# Epoch [203/400], Step [2/5], Loss: 0.2134
# Epoch [203/400], Step [4/5], Loss: 0.2228
# Epoch [204/400], Step [2/5], Loss: 0.2231
# Epoch [204/400], Step [4/5], Loss: 0.2397
# Epoch [205/400], Step [2/5], Loss: 0.2171
# Epoch [205/400], Step [4/5], Loss: 0.2269
# Epoch [206/400], Step [2/5], Loss: 0.2045
# Epoch [206/400], Step [4/5], Loss: 0.2326
# Epoch [207/400], Step [2/5], Loss: 0.2006
# Epoch [207/400], Step [4/5], Loss: 0.2315
# Epoch [208/400], Step [2/5], Loss: 0.2156
# Epoch [208/400], Step [4/5], Loss: 0.2255
# Epoch [209/400], Step [2/5], Loss: 0.2120
# Epoch [209/400], Step [4/5], Loss: 0.2116
# Epoch [210/400], Step [2/5], Loss: 0.2026
# Epoch [210/400], Step [4/5], Loss: 0.2276
# Epoch [211/400], Step [2/5], Loss: 0.2136
# Epoch [211/400], Step [4/5], Loss: 0.1991
# Epoch [212/400], Step [2/5], Loss: 0.2244
# Epoch [212/400], Step [4/5], Loss: 0.2100
# Epoch [213/400], Step [2/5], Loss: 0.2234
# Epoch [213/400], Step [4/5], Loss: 0.2137
# Epoch [214/400], Step [2/5], Loss: 0.2051
# Epoch [214/400], Step [4/5], Loss: 0.2151
# Epoch [215/400], Step [2/5], Loss: 0.2143
# Epoch [215/400], Step [4/5], Loss: 0.1986
# Epoch [216/400], Step [2/5], Loss: 0.2116
# Epoch [216/400], Step [4/5], Loss: 0.2062
# Epoch [217/400], Step [2/5], Loss: 0.2122
# Epoch [217/400], Step [4/5], Loss: 0.2135
# Epoch [218/400], Step [2/5], Loss: 0.1959
# Epoch [218/400], Step [4/5], Loss: 0.2014
# Epoch [219/400], Step [2/5], Loss: 0.1990
# Epoch [219/400], Step [4/5], Loss: 0.2204
# Epoch [220/400], Step [2/5], Loss: 0.2085
# Epoch [220/400], Step [4/5], Loss: 0.2258
# Epoch [221/400], Step [2/5], Loss: 0.2073
# Epoch [221/400], Step [4/5], Loss: 0.2345
# Epoch [222/400], Step [2/5], Loss: 0.1963
# Epoch [222/400], Step [4/5], Loss: 0.1960
# Epoch [223/400], Step [2/5], Loss: 0.2177
# Epoch [223/400], Step [4/5], Loss: 0.1961
# Epoch [224/400], Step [2/5], Loss: 0.2346
# Epoch [224/400], Step [4/5], Loss: 0.2117
# Epoch [225/400], Step [2/5], Loss: 0.1987
# Epoch [225/400], Step [4/5], Loss: 0.2191
# Epoch [226/400], Step [2/5], Loss: 0.1923
# Epoch [226/400], Step [4/5], Loss: 0.1987
# Epoch [227/400], Step [2/5], Loss: 0.1906
# Epoch [227/400], Step [4/5], Loss: 0.2104
# Epoch [228/400], Step [2/5], Loss: 0.2340
# Epoch [228/400], Step [4/5], Loss: 0.2082
# Epoch [229/400], Step [2/5], Loss: 0.2027
# Epoch [229/400], Step [4/5], Loss: 0.2190
# Epoch [230/400], Step [2/5], Loss: 0.2341
# Epoch [230/400], Step [4/5], Loss: 0.1981
# Epoch [231/400], Step [2/5], Loss: 0.1838
# Epoch [231/400], Step [4/5], Loss: 0.2316
# Epoch [232/400], Step [2/5], Loss: 0.2120
# Epoch [232/400], Step [4/5], Loss: 0.1778
# Epoch [233/400], Step [2/5], Loss: 0.1941
# Epoch [233/400], Step [4/5], Loss: 0.1992
# Epoch [234/400], Step [2/5], Loss: 0.1959
# Epoch [234/400], Step [4/5], Loss: 0.1890
# Epoch [235/400], Step [2/5], Loss: 0.2303
# Epoch [235/400], Step [4/5], Loss: 0.1640
# Epoch [236/400], Step [2/5], Loss: 0.1977
# Epoch [236/400], Step [4/5], Loss: 0.1922
# Epoch [237/400], Step [2/5], Loss: 0.1990
# Epoch [237/400], Step [4/5], Loss: 0.1866
# Epoch [238/400], Step [2/5], Loss: 0.2147
# Epoch [238/400], Step [4/5], Loss: 0.1956
# Epoch [239/400], Step [2/5], Loss: 0.1931
# Epoch [239/400], Step [4/5], Loss: 0.1814
# Epoch [240/400], Step [2/5], Loss: 0.2026
# Epoch [240/400], Step [4/5], Loss: 0.1950
# Epoch [241/400], Step [2/5], Loss: 0.1897
# Epoch [241/400], Step [4/5], Loss: 0.2202
# Epoch [242/400], Step [2/5], Loss: 0.1833
# Epoch [242/400], Step [4/5], Loss: 0.1825
# Epoch [243/400], Step [2/5], Loss: 0.2062
# Epoch [243/400], Step [4/5], Loss: 0.1913
# Epoch [244/400], Step [2/5], Loss: 0.1775
# Epoch [244/400], Step [4/5], Loss: 0.1968
# Epoch [245/400], Step [2/5], Loss: 0.2106
# Epoch [245/400], Step [4/5], Loss: 0.1885
# Epoch [246/400], Step [2/5], Loss: 0.1987
# Epoch [246/400], Step [4/5], Loss: 0.2048
# Epoch [247/400], Step [2/5], Loss: 0.2040
# Epoch [247/400], Step [4/5], Loss: 0.2088
# Epoch [248/400], Step [2/5], Loss: 0.1639
# Epoch [248/400], Step [4/5], Loss: 0.1931
# Epoch [249/400], Step [2/5], Loss: 0.1830
# Epoch [249/400], Step [4/5], Loss: 0.1638
# Epoch [250/400], Step [2/5], Loss: 0.2047
# Epoch [250/400], Step [4/5], Loss: 0.1715
# Epoch [251/400], Step [2/5], Loss: 0.1872
# Epoch [251/400], Step [4/5], Loss: 0.1728
# Epoch [252/400], Step [2/5], Loss: 0.1888
# Epoch [252/400], Step [4/5], Loss: 0.1879
# Epoch [253/400], Step [2/5], Loss: 0.1895
# Epoch [253/400], Step [4/5], Loss: 0.1945
# Epoch [254/400], Step [2/5], Loss: 0.2066
# Epoch [254/400], Step [4/5], Loss: 0.1870
# Epoch [255/400], Step [2/5], Loss: 0.1892
# Epoch [255/400], Step [4/5], Loss: 0.2016
# Epoch [256/400], Step [2/5], Loss: 0.1957
# Epoch [256/400], Step [4/5], Loss: 0.2043
# Epoch [257/400], Step [2/5], Loss: 0.2010
# Epoch [257/400], Step [4/5], Loss: 0.1822
# Epoch [258/400], Step [2/5], Loss: 0.2011
# Epoch [258/400], Step [4/5], Loss: 0.1835
# Epoch [259/400], Step [2/5], Loss: 0.1648
# Epoch [259/400], Step [4/5], Loss: 0.2045
# Epoch [260/400], Step [2/5], Loss: 0.1952
# Epoch [260/400], Step [4/5], Loss: 0.1677
# Epoch [261/400], Step [2/5], Loss: 0.1991
# Epoch [261/400], Step [4/5], Loss: 0.1691
# Epoch [262/400], Step [2/5], Loss: 0.1702
# Epoch [262/400], Step [4/5], Loss: 0.1653
# Epoch [263/400], Step [2/5], Loss: 0.1730
# Epoch [263/400], Step [4/5], Loss: 0.1906
# Epoch [264/400], Step [2/5], Loss: 0.1750
# Epoch [264/400], Step [4/5], Loss: 0.1956
# Epoch [265/400], Step [2/5], Loss: 0.1832
# Epoch [265/400], Step [4/5], Loss: 0.1784
# Epoch [266/400], Step [2/5], Loss: 0.1691
# Epoch [266/400], Step [4/5], Loss: 0.1782
# Epoch [267/400], Step [2/5], Loss: 0.1489
# Epoch [267/400], Step [4/5], Loss: 0.2083
# Epoch [268/400], Step [2/5], Loss: 0.1643
# Epoch [268/400], Step [4/5], Loss: 0.1981
# Epoch [269/400], Step [2/5], Loss: 0.1709
# Epoch [269/400], Step [4/5], Loss: 0.1640
# Epoch [270/400], Step [2/5], Loss: 0.1982
# Epoch [270/400], Step [4/5], Loss: 0.1879
# Epoch [271/400], Step [2/5], Loss: 0.1833
# Epoch [271/400], Step [4/5], Loss: 0.1807
# Epoch [272/400], Step [2/5], Loss: 0.1679
# Epoch [272/400], Step [4/5], Loss: 0.1915
# Epoch [273/400], Step [2/5], Loss: 0.1889
# Epoch [273/400], Step [4/5], Loss: 0.1838
# Epoch [274/400], Step [2/5], Loss: 0.1657
# Epoch [274/400], Step [4/5], Loss: 0.1721
# Epoch [275/400], Step [2/5], Loss: 0.1742
# Epoch [275/400], Step [4/5], Loss: 0.1568
# Epoch [276/400], Step [2/5], Loss: 0.1672
# Epoch [276/400], Step [4/5], Loss: 0.1650
# Epoch [277/400], Step [2/5], Loss: 0.1538
# Epoch [277/400], Step [4/5], Loss: 0.1879
# Epoch [278/400], Step [2/5], Loss: 0.1711
# Epoch [278/400], Step [4/5], Loss: 0.1931
# Epoch [279/400], Step [2/5], Loss: 0.1675
# Epoch [279/400], Step [4/5], Loss: 0.1541
# Epoch [280/400], Step [2/5], Loss: 0.1580
# Epoch [280/400], Step [4/5], Loss: 0.1633
# Epoch [281/400], Step [2/5], Loss: 0.1635
# Epoch [281/400], Step [4/5], Loss: 0.1803
# Epoch [282/400], Step [2/5], Loss: 0.1913
# Epoch [282/400], Step [4/5], Loss: 0.1610
# Epoch [283/400], Step [2/5], Loss: 0.1753
# Epoch [283/400], Step [4/5], Loss: 0.1556
# Epoch [284/400], Step [2/5], Loss: 0.1764
# Epoch [284/400], Step [4/5], Loss: 0.1830
# Epoch [285/400], Step [2/5], Loss: 0.1862
# Epoch [285/400], Step [4/5], Loss: 0.1643
# Epoch [286/400], Step [2/5], Loss: 0.1755
# Epoch [286/400], Step [4/5], Loss: 0.1853
# Epoch [287/400], Step [2/5], Loss: 0.1765
# Epoch [287/400], Step [4/5], Loss: 0.1884
# Epoch [288/400], Step [2/5], Loss: 0.1758
# Epoch [288/400], Step [4/5], Loss: 0.1723
# Epoch [289/400], Step [2/5], Loss: 0.1739
# Epoch [289/400], Step [4/5], Loss: 0.1697
# Epoch [290/400], Step [2/5], Loss: 0.1783
# Epoch [290/400], Step [4/5], Loss: 0.1672
# Epoch [291/400], Step [2/5], Loss: 0.1806
# Epoch [291/400], Step [4/5], Loss: 0.1696
# Epoch [292/400], Step [2/5], Loss: 0.1867
# Epoch [292/400], Step [4/5], Loss: 0.1624
# Epoch [293/400], Step [2/5], Loss: 0.1621
# Epoch [293/400], Step [4/5], Loss: 0.1909
# Epoch [294/400], Step [2/5], Loss: 0.1692
# Epoch [294/400], Step [4/5], Loss: 0.1827
# Epoch [295/400], Step [2/5], Loss: 0.1667
# Epoch [295/400], Step [4/5], Loss: 0.1561
# Epoch [296/400], Step [2/5], Loss: 0.1656
# Epoch [296/400], Step [4/5], Loss: 0.1563
# Epoch [297/400], Step [2/5], Loss: 0.1679
# Epoch [297/400], Step [4/5], Loss: 0.1781
# Epoch [298/400], Step [2/5], Loss: 0.1583
# Epoch [298/400], Step [4/5], Loss: 0.1708
# Epoch [299/400], Step [2/5], Loss: 0.1522
# Epoch [299/400], Step [4/5], Loss: 0.1819
# Epoch [300/400], Step [2/5], Loss: 0.1599
# Epoch [300/400], Step [4/5], Loss: 0.1663
# Epoch [301/400], Step [2/5], Loss: 0.1736
# Epoch [301/400], Step [4/5], Loss: 0.1747
# Epoch [302/400], Step [2/5], Loss: 0.1816
# Epoch [302/400], Step [4/5], Loss: 0.1613
# Epoch [303/400], Step [2/5], Loss: 0.1464
# Epoch [303/400], Step [4/5], Loss: 0.1664
# Epoch [304/400], Step [2/5], Loss: 0.1595
# Epoch [304/400], Step [4/5], Loss: 0.1539
# Epoch [305/400], Step [2/5], Loss: 0.1440
# Epoch [305/400], Step [4/5], Loss: 0.1631
# Epoch [306/400], Step [2/5], Loss: 0.1865
# Epoch [306/400], Step [4/5], Loss: 0.1524
# Epoch [307/400], Step [2/5], Loss: 0.1594
# Epoch [307/400], Step [4/5], Loss: 0.1732
# Epoch [308/400], Step [2/5], Loss: 0.1920
# Epoch [308/400], Step [4/5], Loss: 0.1479
# Epoch [309/400], Step [2/5], Loss: 0.1788
# Epoch [309/400], Step [4/5], Loss: 0.1765
# Epoch [310/400], Step [2/5], Loss: 0.1376
# Epoch [310/400], Step [4/5], Loss: 0.1845
# Epoch [311/400], Step [2/5], Loss: 0.1631
# Epoch [311/400], Step [4/5], Loss: 0.1433
# Epoch [312/400], Step [2/5], Loss: 0.1774
# Epoch [312/400], Step [4/5], Loss: 0.1612
# Epoch [313/400], Step [2/5], Loss: 0.1596
# Epoch [313/400], Step [4/5], Loss: 0.1588
# Epoch [314/400], Step [2/5], Loss: 0.1615
# Epoch [314/400], Step [4/5], Loss: 0.1635
# Epoch [315/400], Step [2/5], Loss: 0.1663
# Epoch [315/400], Step [4/5], Loss: 0.1522
# Epoch [316/400], Step [2/5], Loss: 0.1562
# Epoch [316/400], Step [4/5], Loss: 0.1635
# Epoch [317/400], Step [2/5], Loss: 0.1471
# Epoch [317/400], Step [4/5], Loss: 0.1519
# Epoch [318/400], Step [2/5], Loss: 0.1880
# Epoch [318/400], Step [4/5], Loss: 0.1502
# Epoch [319/400], Step [2/5], Loss: 0.1435
# Epoch [319/400], Step [4/5], Loss: 0.1774
# Epoch [320/400], Step [2/5], Loss: 0.1648
# Epoch [320/400], Step [4/5], Loss: 0.1530
# Epoch [321/400], Step [2/5], Loss: 0.1409
# Epoch [321/400], Step [4/5], Loss: 0.1533
# Epoch [322/400], Step [2/5], Loss: 0.1483
# Epoch [322/400], Step [4/5], Loss: 0.1646
# Epoch [323/400], Step [2/5], Loss: 0.1734
# Epoch [323/400], Step [4/5], Loss: 0.1499
# Epoch [324/400], Step [2/5], Loss: 0.1474
# Epoch [324/400], Step [4/5], Loss: 0.1588
# Epoch [325/400], Step [2/5], Loss: 0.1584
# Epoch [325/400], Step [4/5], Loss: 0.1581
# Epoch [326/400], Step [2/5], Loss: 0.1652
# Epoch [326/400], Step [4/5], Loss: 0.1593
# Epoch [327/400], Step [2/5], Loss: 0.1395
# Epoch [327/400], Step [4/5], Loss: 0.1756
# Epoch [328/400], Step [2/5], Loss: 0.1414
# Epoch [328/400], Step [4/5], Loss: 0.1754
# Epoch [329/400], Step [2/5], Loss: 0.1455
# Epoch [329/400], Step [4/5], Loss: 0.1684
# Epoch [330/400], Step [2/5], Loss: 0.1698
# Epoch [330/400], Step [4/5], Loss: 0.1467
# Epoch [331/400], Step [2/5], Loss: 0.1588
# Epoch [331/400], Step [4/5], Loss: 0.1402
# Epoch [332/400], Step [2/5], Loss: 0.1452
# Epoch [332/400], Step [4/5], Loss: 0.1586
# Epoch [333/400], Step [2/5], Loss: 0.1492
# Epoch [333/400], Step [4/5], Loss: 0.1736
# Epoch [334/400], Step [2/5], Loss: 0.1543
# Epoch [334/400], Step [4/5], Loss: 0.1718
# Epoch [335/400], Step [2/5], Loss: 0.1717
# Epoch [335/400], Step [4/5], Loss: 0.1385
# Epoch [336/400], Step [2/5], Loss: 0.1743
# Epoch [336/400], Step [4/5], Loss: 0.1709
# Epoch [337/400], Step [2/5], Loss: 0.1497
# Epoch [337/400], Step [4/5], Loss: 0.1515
# Epoch [338/400], Step [2/5], Loss: 0.1323
# Epoch [338/400], Step [4/5], Loss: 0.1649
# Epoch [339/400], Step [2/5], Loss: 0.1608
# Epoch [339/400], Step [4/5], Loss: 0.1398
# Epoch [340/400], Step [2/5], Loss: 0.1535
# Epoch [340/400], Step [4/5], Loss: 0.1669
# Epoch [341/400], Step [2/5], Loss: 0.1668
# Epoch [341/400], Step [4/5], Loss: 0.1472
# Epoch [342/400], Step [2/5], Loss: 0.1609
# Epoch [342/400], Step [4/5], Loss: 0.1533
# Epoch [343/400], Step [2/5], Loss: 0.1528
# Epoch [343/400], Step [4/5], Loss: 0.1664
# Epoch [344/400], Step [2/5], Loss: 0.1581
# Epoch [344/400], Step [4/5], Loss: 0.1378
# Epoch [345/400], Step [2/5], Loss: 0.1667
# Epoch [345/400], Step [4/5], Loss: 0.1462
# Epoch [346/400], Step [2/5], Loss: 0.1536
# Epoch [346/400], Step [4/5], Loss: 0.1450
# Epoch [347/400], Step [2/5], Loss: 0.1442
# Epoch [347/400], Step [4/5], Loss: 0.1596
# Epoch [348/400], Step [2/5], Loss: 0.1537
# Epoch [348/400], Step [4/5], Loss: 0.1556
# Epoch [349/400], Step [2/5], Loss: 0.1269
# Epoch [349/400], Step [4/5], Loss: 0.1455
# Epoch [350/400], Step [2/5], Loss: 0.1479
# Epoch [350/400], Step [4/5], Loss: 0.1576
# Epoch [351/400], Step [2/5], Loss: 0.1707
# Epoch [351/400], Step [4/5], Loss: 0.1609
# Epoch [352/400], Step [2/5], Loss: 0.1484
# Epoch [352/400], Step [4/5], Loss: 0.1434
# Epoch [353/400], Step [2/5], Loss: 0.1454
# Epoch [353/400], Step [4/5], Loss: 0.1813
# Epoch [354/400], Step [2/5], Loss: 0.1467
# Epoch [354/400], Step [4/5], Loss: 0.1653
# Epoch [355/400], Step [2/5], Loss: 0.1456
# Epoch [355/400], Step [4/5], Loss: 0.1473
# Epoch [356/400], Step [2/5], Loss: 0.1493
# Epoch [356/400], Step [4/5], Loss: 0.1317
# Epoch [357/400], Step [2/5], Loss: 0.1571
# Epoch [357/400], Step [4/5], Loss: 0.1577
# Epoch [358/400], Step [2/5], Loss: 0.1488
# Epoch [358/400], Step [4/5], Loss: 0.1333
# Epoch [359/400], Step [2/5], Loss: 0.1376
# Epoch [359/400], Step [4/5], Loss: 0.1607
# Epoch [360/400], Step [2/5], Loss: 0.1752
# Epoch [360/400], Step [4/5], Loss: 0.1378
# Epoch [361/400], Step [2/5], Loss: 0.1451
# Epoch [361/400], Step [4/5], Loss: 0.1494
# Epoch [362/400], Step [2/5], Loss: 0.1567
# Epoch [362/400], Step [4/5], Loss: 0.1473
# Epoch [363/400], Step [2/5], Loss: 0.1402
# Epoch [363/400], Step [4/5], Loss: 0.1674
# Epoch [364/400], Step [2/5], Loss: 0.1778
# Epoch [364/400], Step [4/5], Loss: 0.1363
# Epoch [365/400], Step [2/5], Loss: 0.1414
# Epoch [365/400], Step [4/5], Loss: 0.1607
# Epoch [366/400], Step [2/5], Loss: 0.1408
# Epoch [366/400], Step [4/5], Loss: 0.1481
# Epoch [367/400], Step [2/5], Loss: 0.1576
# Epoch [367/400], Step [4/5], Loss: 0.1735
# Epoch [368/400], Step [2/5], Loss: 0.1407
# Epoch [368/400], Step [4/5], Loss: 0.1626
# Epoch [369/400], Step [2/5], Loss: 0.1493
# Epoch [369/400], Step [4/5], Loss: 0.1388
# Epoch [370/400], Step [2/5], Loss: 0.1567
# Epoch [370/400], Step [4/5], Loss: 0.1416
# Epoch [371/400], Step [2/5], Loss: 0.1499
# Epoch [371/400], Step [4/5], Loss: 0.1562
# Epoch [372/400], Step [2/5], Loss: 0.1463
# Epoch [372/400], Step [4/5], Loss: 0.1358
# Epoch [373/400], Step [2/5], Loss: 0.1644
# Epoch [373/400], Step [4/5], Loss: 0.1639
# Epoch [374/400], Step [2/5], Loss: 0.1612
# Epoch [374/400], Step [4/5], Loss: 0.1523
# Epoch [375/400], Step [2/5], Loss: 0.1640
# Epoch [375/400], Step [4/5], Loss: 0.1522
# Epoch [376/400], Step [2/5], Loss: 0.1580
# Epoch [376/400], Step [4/5], Loss: 0.1372
# Epoch [377/400], Step [2/5], Loss: 0.1849
# Epoch [377/400], Step [4/5], Loss: 0.1331
# Epoch [378/400], Step [2/5], Loss: 0.1489
# Epoch [378/400], Step [4/5], Loss: 0.1382
# Epoch [379/400], Step [2/5], Loss: 0.1314
# Epoch [379/400], Step [4/5], Loss: 0.1499
# Epoch [380/400], Step [2/5], Loss: 0.1441
# Epoch [380/400], Step [4/5], Loss: 0.1486
# Epoch [381/400], Step [2/5], Loss: 0.1415
# Epoch [381/400], Step [4/5], Loss: 0.1674
# Epoch [382/400], Step [2/5], Loss: 0.1599
# Epoch [382/400], Step [4/5], Loss: 0.1492
# Epoch [383/400], Step [2/5], Loss: 0.1352
# Epoch [383/400], Step [4/5], Loss: 0.1320
# Epoch [384/400], Step [2/5], Loss: 0.1641
# Epoch [384/400], Step [4/5], Loss: 0.1395
# Epoch [385/400], Step [2/5], Loss: 0.1380
# Epoch [385/400], Step [4/5], Loss: 0.1561
# Epoch [386/400], Step [2/5], Loss: 0.1454
# Epoch [386/400], Step [4/5], Loss: 0.1376
# Epoch [387/400], Step [2/5], Loss: 0.1748
# Epoch [387/400], Step [4/5], Loss: 0.1475
# Epoch [388/400], Step [2/5], Loss: 0.1463
# Epoch [388/400], Step [4/5], Loss: 0.1782
# Epoch [389/400], Step [2/5], Loss: 0.1698
# Epoch [389/400], Step [4/5], Loss: 0.1327
# Epoch [390/400], Step [2/5], Loss: 0.1387
# Epoch [390/400], Step [4/5], Loss: 0.1320
# Epoch [391/400], Step [2/5], Loss: 0.1600
# Epoch [391/400], Step [4/5], Loss: 0.1496
# Epoch [392/400], Step [2/5], Loss: 0.1639
# Epoch [392/400], Step [4/5], Loss: 0.1411
# Epoch [393/400], Step [2/5], Loss: 0.1469
# Epoch [393/400], Step [4/5], Loss: 0.1508
# Epoch [394/400], Step [2/5], Loss: 0.1652
# Epoch [394/400], Step [4/5], Loss: 0.1444
# Epoch [395/400], Step [2/5], Loss: 0.1536
# Epoch [395/400], Step [4/5], Loss: 0.1637
# Epoch [396/400], Step [2/5], Loss: 0.1448
# Epoch [396/400], Step [4/5], Loss: 0.1531
# Epoch [397/400], Step [2/5], Loss: 0.1683
# Epoch [397/400], Step [4/5], Loss: 0.1441
# Epoch [398/400], Step [2/5], Loss: 0.1685
# Epoch [398/400], Step [4/5], Loss: 0.1470
# Epoch [399/400], Step [2/5], Loss: 0.1433
# Epoch [399/400], Step [4/5], Loss: 0.1526
# Epoch [400/400], Step [2/5], Loss: 0.1524
# Epoch [400/400], Step [4/5], Loss: 0.1415
# Epoch [199/200], Step [4/5], Loss: 0.1942
# Epoch [200/200], Step [2/5], Loss: 0.1872
# Epoch [200/200], Step [4/5], Loss: 0.1819

# %%
test_dataset = CustomDataset(test_paths)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                           batch_size=4, 
                                           shuffle=False)
dataset = test_dataset

with torch.no_grad():
    figure = plt.figure(figsize=(10, 8))
    rows = 2
    for i in range(0, rows):
        sample_idx = torch.randint(len(dataset), size=(1,)).item()
        img, label = dataset[sample_idx]
        b_x = img.unsqueeze(0)
        output = model(b_x)

        figure.add_subplot(rows, 3, 3*i + 1)
        plt.axis("off")
        plt.imshow(img.permute(1,2,0))
        plt.title("image")
        figure.add_subplot(rows, 3, 3*i + 2)
        plt.axis("off")
        plt.imshow(torch.squeeze(output), cmap="gray")
        plt.title("model output")
        figure.add_subplot(rows, 3, 3*i + 3)
        plt.axis("off")
        plt.imshow(torch.squeeze(label), cmap="gray")
        plt.title("ground truth")
    plt.show()

# %% [markdown]
# ## 5. Image Denoising with MNIST
#
# - Problem setup: Suppose we have an observed noisy image $x$, and we wish to recover a clean version of the image, $u$. We model using additive gaussian noise: $x = u + \epsilon$ where $\epsilon$ is the noise.
# - Let us set the data up, by extracting the MNIST images and adding gaussian noise to them.

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

train_data = datasets.MNIST(
    root = 'data',
    train = True,                         
    transform = ToTensor(), 
    download = True)
test_data = datasets.MNIST(
    root = 'data', 
    train = False, 
    transform = ToTensor()
)

# %%
train_imgs = train_data.data
print(train_imgs.shape)
train_imgs = train_imgs.numpy() # pixel of 0 is black, pixel of 255 is white
# store the clean images before adding noise
train_imgs0 = train_imgs/255.0 # [0,1]

test_imgs = test_data.data
test_imgs = test_imgs.numpy()
test_imgs0 = test_imgs/255.0

sigma = 70/255.0 # noise level
train_imgs = (train_imgs/255.0 + np.random.normal(0,sigma,train_imgs.shape)).clip(0,1)
test_imgs = (test_imgs/255.0 + np.random.normal(0,sigma,test_imgs.shape)).clip(0,1)


fig = plt.figure()
plt.subplot(1,2,1)
plt.imshow(train_imgs0[0],cmap='gray')
plt.subplot(1,2,2)
plt.imshow(train_imgs[0],cmap='gray')
plt.show()
# Out:
# torch.Size([60000, 28, 28])

# %%
model = CNN(in_channels=1, out_channels = 1).to(device)

# %%
learning_rate = 0.001

optimizer = optim.Adam(model.parameters(), lr = learning_rate)   
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )

# %%
total_step = len(train_imgs)
print(total_step)
train_imgs.shape
# Out:
# 60000
# (60000, 28, 28)

# %%
loaders = {
    'train' : torch.utils.data.DataLoader(train_imgs, 
                                          batch_size=100, 
                                          shuffle=True, 
                                          num_workers=1),
    
    'test'  : torch.utils.data.DataLoader(test_imgs, 
                                          batch_size=100, 
                                          shuffle=True, 
                                          num_workers=1),
}
loaders
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x1969f77e800>,
#  'test': <torch.utils.data.dataloader.DataLoader at 0x1969f77f250>}

# %% [markdown]
# ## Loss Function:
#
# - In our denoising setup we assume no label. Our dataset consists of only observed noisy images, i.e. $\mathcal{D} = \{ \mathbf{x}_i \in \mathbb{R}^{h \times w} \}_{k=1}^n$. This approach (not using labels) is known as **unsupervised learning**.
#
# - We will implement a classic denoising model, which is composed of two terms:
# $$ \mathcal{L}(\theta) = \sum_{k=1}^n || \nabla f(\mathbf{x}_i;\theta) ||_2 + \frac{\lambda}{2} || f(\mathbf{x}_i; \theta) - \mathbf{x}_i ||_2^2 , $$
# - where $\lambda>0$ is a parameter which we hand tune according to the strength of noise. If we have a large $\lambda$, the second term is more dominiant and our network output will be matched more closely to the input (i.e. $f(\mathbf{x}_i ; \theta) \approx \mathbf{x}_i$). If $\lambda$ is small, the first term will be more dominant and more smoothing will occur.

# %%
def up_shift(f):
    g = torch.zeros_like(f)
    g[:-1, :] = f[1:, :] #i.e. g[0,:] = f[1,:], g[1,:] = f[2,:], ..., g[i,:] = f[i+1,:]
    g[-1, :] = f[-1, :]
    return g

def down_shift(f):
    g = torch.zeros_like(f)
    g[1:, :] = f[:-1, :]
    g[0, :] = f[0, :]
    return g

def left_shift(f):
    g = torch.zeros_like(f)
    g[:, :-1] = f[:, 1:]
    g[:, -1] = f[:, -1]
    return g

def right_shift(f):
    g = torch.zeros_like(f)
    g[:, 1:] = f[:, :-1]
    g[:, 0] = f[:, 0]
    return g


def grad(f):
    f_x = (left_shift(f) - right_shift(f))/2
    f_y = (down_shift(f) - up_shift(f))/2
    
    return torch.sqrt(f_x**2 + f_y**2 + 1e-7)

class denoising_loss(nn.Module):
    def __init__(self):
        super().__init__()
        
    def forward(self, denoised, noisy, lambdaP):
        
        TV_term = grad(denoised)
        
        Fit_Term = (denoised-noisy)**2
        
        loss = TV_term.mean() + (lambdaP/2)*Fit_Term.mean()

        return loss

# %%
from torch.autograd import Variable
num_epochs = 10
lambdaP = 8
loss_func = denoising_loss()
def train(num_epochs, model, loaders):
    
    model.train()
        
    # Train the model
    total_step = len(loaders['train'])
        
    for epoch in range(num_epochs):
        for i, images in enumerate(loaders['train']):
            
            # gives batch data, normalize x when iterate train_loader
            b_x = Variable(images, requires_grad=True).to(device)   # batch x. b_x is of shape [100,28,28]
            #print(b_x.shape)
            b_x = b_x.unsqueeze(1) # make dimensions [100,1,28,28], rather than [100,28,28]
            #print(b_x.shape)
            output = model(b_x.float())  

            #print(output.shape)
            loss = loss_func(output,b_x,lambdaP)
                        
            # clear gradients for this training step   
            optimizer.zero_grad()           
            
            # backpropagation, compute gradients 
            loss.backward()                # apply gradients             
            optimizer.step()                
            
            if (i+1) % 100 == 0:
                print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                       .format(epoch + 1, num_epochs, i + 1, total_step, loss.item()))               
        
    
    
train(num_epochs, model, loaders)
# Out:
# Epoch [1/10], Step [100/600], Loss: 0.2844
# Epoch [1/10], Step [200/600], Loss: 0.2536
# Epoch [1/10], Step [300/600], Loss: 0.2327
# Epoch [1/10], Step [400/600], Loss: 0.2272
# Epoch [1/10], Step [500/600], Loss: 0.2213
# Epoch [1/10], Step [600/600], Loss: 0.2213
# Epoch [2/10], Step [100/600], Loss: 0.2202
# Epoch [2/10], Step [200/600], Loss: 0.2218
# Epoch [2/10], Step [300/600], Loss: 0.2149
# Epoch [2/10], Step [400/600], Loss: 0.2160
# Epoch [2/10], Step [500/600], Loss: 0.2157
# Epoch [2/10], Step [600/600], Loss: 0.2152
# Epoch [3/10], Step [100/600], Loss: 0.2122
# Epoch [3/10], Step [200/600], Loss: 0.2170
# Epoch [3/10], Step [300/600], Loss: 0.2157
# Epoch [3/10], Step [400/600], Loss: 0.2121
# Epoch [3/10], Step [500/600], Loss: 0.2129
# Epoch [3/10], Step [600/600], Loss: 0.2127
# Epoch [4/10], Step [100/600], Loss: 0.2123
# Epoch [4/10], Step [200/600], Loss: 0.2093
# Epoch [4/10], Step [300/600], Loss: 0.2131
# Epoch [4/10], Step [400/600], Loss: 0.2122
# Epoch [4/10], Step [500/600], Loss: 0.2060
# Epoch [4/10], Step [600/600], Loss: 0.2086
# Epoch [5/10], Step [100/600], Loss: 0.2086
# Epoch [5/10], Step [200/600], Loss: 0.2116
# Epoch [5/10], Step [300/600], Loss: 0.2103
# Epoch [5/10], Step [400/600], Loss: 0.2144
# Epoch [5/10], Step [500/600], Loss: 0.2141
# Epoch [5/10], Step [600/600], Loss: 0.2103
# Epoch [6/10], Step [100/600], Loss: 0.2142
# Epoch [6/10], Step [200/600], Loss: 0.2077
# Epoch [6/10], Step [300/600], Loss: 0.2042
# Epoch [6/10], Step [400/600], Loss: 0.2099
# Epoch [6/10], Step [500/600], Loss: 0.2057
# Epoch [6/10], Step [600/600], Loss: 0.2067
# Epoch [7/10], Step [100/600], Loss: 0.2083
# Epoch [7/10], Step [200/600], Loss: 0.2095
# Epoch [7/10], Step [300/600], Loss: 0.2100
# Epoch [7/10], Step [400/600], Loss: 0.2086
# Epoch [7/10], Step [500/600], Loss: 0.2040
# Epoch [7/10], Step [600/600], Loss: 0.2070
# Epoch [8/10], Step [100/600], Loss: 0.2087
# Epoch [8/10], Step [200/600], Loss: 0.2033
# Epoch [8/10], Step [300/600], Loss: 0.2109
# Epoch [8/10], Step [400/600], Loss: 0.2070
# Epoch [8/10], Step [500/600], Loss: 0.2029
# Epoch [8/10], Step [600/600], Loss: 0.2047
# Epoch [9/10], Step [100/600], Loss: 0.2110
# Epoch [9/10], Step [200/600], Loss: 0.2060
# Epoch [9/10], Step [300/600], Loss: 0.2121
# Epoch [9/10], Step [400/600], Loss: 0.2110
# Epoch [9/10], Step [500/600], Loss: 0.2067
# Epoch [9/10], Step [600/600], Loss: 0.2074
# Epoch [10/10], Step [100/600], Loss: 0.2104
# Epoch [10/10], Step [200/600], Loss: 0.2025
# Epoch [10/10], Step [300/600], Loss: 0.2103
# Epoch [10/10], Step [400/600], Loss: 0.2102
# Epoch [10/10], Step [500/600], Loss: 0.2115
# Epoch [10/10], Step [600/600], Loss: 0.2107

# %%
with torch.no_grad():
    #Plot multiple
    figure = plt.figure(figsize=(15, 12))
    cols, rows =4,4
    for i in range(1, int((cols * rows)/2) + 1):
        sample_idx = torch.randint(len(test_imgs), size=(1,)).item()
        noisy, clean = test_imgs[sample_idx], test_imgs0[sample_idx]
        noisy = noisy[np.newaxis,np.newaxis,:,:] #[1,1,height,width]
        b_x = torch.from_numpy(noisy).float()
        b_x = b_x.to(device)
        output = model(b_x)
        output = output.cpu()

        figure.add_subplot(rows,cols,2*i - 1)
        plt.title('noisy input')
        plt.axis("off")
        plt.imshow(noisy.squeeze(),cmap="gray")

        figure.add_subplot(rows,cols,2*i)
        plt.title('net denoised')
        plt.axis("off")
        plt.imshow(output.squeeze(),cmap="gray")

    plt.show()

# %% [markdown]
# ## Homework
#
# - Try training the segmentation problem again with DICE loss function.
# - The DICE coefficient is a measure of how well two sets coincide with one another, i.e. how well two segmentation results are similar. We use the output of our network, $u$, and the ground truth, $GT$, to measure performance.
# $$ DICE(u,GT) = \frac{ 2 \cdot | u \cdot GT |}{|u| + |GT|} $$
# <p align="center">
# <img src="dice.png" width="250" title="DICE." >
# </p>
#
# - A score of 1 is a perfect match, whereas a score of 0 is the opposite. We want a score of 1 in segmentation.
# - To use this in a loss function, the loss function looks like:
# $$ DICELOSS(u,GT) = 1 - DICE(u,GT) $$

# %%
class DiceLoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceLoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):
        
        ###comment out if your model contains a sigmoid or equivalent activation layer
        #inputs = F.sigmoid(inputs)       
        
        ###flatten label and prediction tensors
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        
        intersection = (inputs * targets).sum()                            
        dice = (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)  
        
        return 1 - dice
